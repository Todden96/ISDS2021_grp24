# %%
# Imports
import pandas as pd
import requests
from datetime import datetime
import numpy as np
from time import sleep
from tqdm import tqdm
import os

# %%
# Paths

#Path to completed DataFrames
path1 = r"C:\Users\Johan\OneDrive - University of Copenhagen\8. Semester\ISDS\ISDS2021_grp24\Exam\Tags_DataFrames_Output"
#individual path to genre tags
path2 = 'https://raw.githubusercontent.com/Todden96/ISDS2021_grp24/main/Exam/genre_tags%20-%20Morten'

#path to saved tags Dataframes on containing the top 100 game ids
path3 = r"C:\Users\Johan\OneDrive - University of Copenhagen\8. Semester\ISDS\ISDS2021_grp24\Exam\Tags_DataFrames"

# %%
tags_list = ['Indie',
             'Low Confidence Metric',
             'Action',
             'Casual',
             'Adventure',
             'Singleplayer',
             'Simulation',
             'Strategy',
             'RPG',
             '2D',
             'Atmospheric',
             'Puzzle',
             'Free to Play',
             'Early Access',
             'Story Rich',
             'Multiplayer',
             'Pixel Graphics',
             'Fantasy',
             '3D',
             'Colorful',
             'Anime',
             'First-Person',
             'Violent',
             'Cute',
             'Exploration',
             'Arcade',
             'Nudity',
             'Funny',
             'Sexual Content',
             'Sci-fi',
             'Shooter',
             'VR',
             'Platformer',
             'Horror',
             'Great Soundtrack',
             'Retro',
             'Gore',
             'Family Friendly',
             'Relaxing',
             'Difficult',
             'Sports',
             'Open World',
             'Female Protagonist',
             'Action-Adventure',
             'Survival',
             'Co-op',
             'Visual Novel',
             'Third Person',
             'Racing',
             'Comedy',
             'FPS',
             'Massively Multiplayer',
             'Stylized',
             'Realistic',
             'Old School',
             'Top-Down',
             'Sandbox',
             'Physics',
             'Turn-Based',
             'Online Co-Op',
             'PvP',
             "Shoot 'Em Up",
             'Choices Matter',
             'Mystery',
             'Point & Click',
             'Space',
             'Minimalist',
             'Cartoony',
             '2D Platformer',
             'Dark',
             'Psychological Horror',
             'Combat',
             'Management',
             'Adult Content',
             'Controller',
             'Building',
             'Side Scroller',
             'Multiple Endings',
             'Tactical',
             'Character Customization',
             'Local Multiplayer',
             'Puzzle-Platformer',
             'Replay Value',
             'Hand-drawn',
             'Design & Illustration',
             'Action RPG',
             'Linear',
             '1980s',
             'Turn-Based Strategy',
             'Education',
             'Magic',
             'Rogue-like',
             'Procedural Generation',
             'Futuristic',
             'Crafting',
             'PvE',
             'Survival Horror',
             'Party-Based RPG',
             'Local Co-Op',
             'Rogue-lite',
             'Mature',
             'Turn-Based Combat',
             'Logic',
             'Software',
             'Medieval',
             'Cartoon',
             'JRPG',
             'Zombies',
             'Hidden Object',
             '3D Platformer',
             'Utilities',
             'Historical',
             'War',
             'Romance',
             'Resource Management',
             'Hack and Slash',
             'Turn-Based Tactics',
             'Classic',
             'Choose Your Own Adventure',
             'Short',
             'Fast-Paced',
             'Bullet Hell',
             'Interactive Fiction',
             'Drama',
             'Walking Simulator',
             'Post-apocalyptic',
             'Movie',
             'Dark Fantasy',
             'Dungeon Crawler',
             'Web Publishing',
             'Stealth',
             'RPGMaker',
             'Surreal',
             'RTS',
             'Base Building',
             'Memes',
             'Top-Down Shooter',
             'Dating Sim',
             'Isometric',
             'Score Attack',
             'Experimental',
             'Military',
             "1990's",
             'Music',
             'Card Game',
             'Narration',
             'Cyberpunk',
             'Text-Based',
             'Third-Person Shooter',
             'Fighting',
             'Abstract',
             'Soundtrack',
             'Driving',
             'Hentai',
             '2.5D',
             'Emotional',
             'Robots',
             'Immersive Sim',
             'Action Roguelike',
             'Board Game',
             '4 Player Local',
             'Flight',
             'Tower Defense',
             'Nature',
             'Economy',
             'LGBTQ+',
             'Aliens',
             'Dark Humor',
             'Competitive',
             'Detective',
             'Investigation',
             'Perma Death',
             'Tabletop',
             'City Builder',
             'Beautiful',
             'Team-Based',
             'Clicker',
             'Arena Shooter',
             'Cinematic',
             'Precision Platformer',
             'Metroidvania',
             'Time Management',
             'Real Time Tactics',
             'NSFW',
             "Beat 'em up",
             'Strategy RPG',
             'Life Sim',
             'Conversation',
             'Thriller',
             'Wargame',
             'Moddable',
             'Psychological',
             'Psychedelic',
             'Tactical RPG',
             'Tutorial',
             'Demons',
             'Animation & Modeling',
             'Level Editor',
             'Character Action Game',
             'Automobile Sim',
             'Destruction',
             'Nonlinear',
             'Twin Stick Shooter',
             'Modern',
             'Dystopian',
             'Runner',
             'Comic Book',
             'World War II',
             'Alternate History',
             'Lore-Rich',
             'Crime',
             '2D Fighter',
             'Rhythm',
             'Audio Production',
             'Loot',
             'Parkour',
             'Grand Strategy',
             'Artificial Intelligence',
             'Game Development',
             'Supernatural',
             'Souls-like',
             'Match 3',
             'Inventory Management',
             'Space Sim',
             'Grid-Based Movement',
             'MMORPG',
             'CRPG',
             'Science',
             'Dark Comedy',
             'Mythology',
             'Philosophical',
             'Lovecraftian',
             'Open World Survival Craft',
             'Collectathon',
             'Split Screen',
             'Video Production',
             'Mouse only',
             'Cats',
             'Addictive',
             'Card Battler',
             'Deckbuilding',
             'Noir',
             'Episodic',
             'Idler',
             'Software Training',
             'Swordplay',
             'Battle Royale',
             'eSports',
             'Voxel',
             'Dragons',
             'Real-Time',
             'Blood',
             '6DOF',
             'Steampunk',
             'Mechs',
             'Colony Sim',
             '3D Fighter',
             'Vehicular Combat',
             'Tanks',
             'Parody',
             'Political',
             'Bullet Time',
             'Class-Based',
             'Farming Sim',
             'Time Manipulation',
             '3D Vision',
             '4X',
             'Pirates',
             'Word Game',
             'Cult Classic',
             'Co-op Campaign',
             'Mystery Dungeon',
             'Hex Grid',
             'Capitalism',
             'Solitaire',
             'Gun Customization',
             'America',
             'Ninja',
             'Satire',
             'Trains',
             'Gothic',
             'Trading',
             'Hero Shooter',
             'Hunting',
             'Hacking',
             'Agriculture',
             'FMV',
             'Otome',
             'Time Travel',
             'Photo Editing',
             'Real-Time with Pause',
             'Combat Racing',
             'God Game',
             'Conspiracy',
             'Automation',
             'Remake',
             'Naval',
             'Mining',
             'Martial Arts',
             'Western',
             'Dinosaurs',
             'Spectacle fighter',
             'Sokoban',
             'Underwater',
             'MOBA',
             'Underground',
             'Politics',
             'Programming',
             'Dog',
             'Dungeons & Dragons',
             'Creature Collector',
             'Trading Card Game',
             'Touch-Friendly',
             'Fishing',
             'Illuminati',
             'Superhero',
             'GameMaker',
             'Vampire',
             'Cold War',
             'Political Sim',
             'Looter Shooter',
             'Dynamic Narration',
             'Kickstarter',
             'Faith',
             'Minigames',
             'Quick-Time Events',
             'Assassin',
             'Experience',
             'Documentary',
             'Asynchronous Multiplayer',
             'Naval Combat',
             'Music-Based Procedural Generation',
             'Soccer',
             'Party Game',
             'Narrative',
             'Time Attack',
             'Archery',
             'Auto Battler',
             'Heist',
             'Typing',
             'On-Rails Shooter',
             'Football',
             'Transportation',
             'Party',
             'Diplomacy',
             'Immersive',
             'Sailing',
             'Cooking',
             'Villain Protagonist',
             'Mod',
             'Chess',
             'Trivia',
             'Snow',
             'Offroad',
             'Epic',
             'Foreign',
             'Mars',
             'TrackIR',
             'Sequel',
             'Horses',
             '360 Video',
             'Sniper',
             'World War I',
             'Gambling',
             'Crowdfunded',
             'Boxing',
             'Gaming',
             'LEGO',
             'Silent Protagonist',
             'Traditional Roguelike',
             'Roguelike Deckbuilder',
             'Pinball',
             'Werewolves',
             'Based On A Novel',
             'Unforgiving',
             'Games Workshop',
             'Transhumanism',
             'Rome',
             'Action RTS',
             'Warhammer 40K',
             'Nostalgia',
             'Golf',
             'Medical Sim',
             'Motorbike',
             'Electronic Music',
             'Ambient',
             'Farming',
             'Jet',
             'Outbreak Sim',
             'Spelling',
             'Bikes',
             'Submarine',
             'Basketball',
             'Asymmetric VR',
             'Social Deduction',
             'Roguevania',
             'Mini Golf',
             'Spaceships',
             'Escape Room',
             'Intentionally Awkward Controls',
             'Wrestling',
             'Lemmings',
             'Instrumental Music',
             'Pool',
             'Baseball',
             'Tennis',
             'Hockey',
             'Skateboarding',
             'Vikings',
             'Motocross',
             'Feature Film',
             'Skating',
             'Electronic',
             'Cycling',
             'Bowling',
             'Rock Music',
             'Voice Control',
             'Benchmark',
             'ATV',
             'Skiing',
             'Snowboarding',
             'Well-Written',
             'Hardware',
             '8-bit Music',
             'BMX',
             'Steam Machine',
             'Reboot']
lang_list = ['Arabic',
             'Bulgarian',
             'Chinese (Simplified)',
             'Chinese (Traditional)',
             'Czech',
             'Danish',
             'Dutch',
             'English',
             'Finnish',
             'French',
             'German',
             'Greek',
             'Hungarian',
             'Italian',
             'Japanese',
             'Korean',
             'Norwegian',
             'Polish',
             'Portuguese',
             'Portuguese - Brazil',
             'Romanian',
             'Russian',
             'Spanish - Spain',
             'Spanish - Latin America',
             'Swedish',
             'Thai',
             'Turkish',
             'Ukrainian',
             'Vietnamese']

# %%
def steam_info(id):
 spy_api = 'https://steamspy.com/api.php?request=appdetails&appid='+ str(id) +''
 steam_api = 'http://store.steampowered.com/api/appdetails?appids='+ str(id) +'&cc=us'

 if bool(requests.get(steam_api).json()[str(id)]['success']) == True:
     spy_api_page = requests.get(spy_api).json()
     steam_api_page = requests.get(steam_api).json()[str(id)]['data']

     # Dataframe
     if steam_api_page['type'] == 'game':


        d = pd.DataFrame(0, index=np.arange(len(header_column)), columns=header_column)

        # if steam_api_page['supported_languages'] is not None:
        try:
            for item in steam_api_page['supported_languages'].split(", "):
             if item in lang_list:
              d[item] = 1
        except Exception:
              pass
        # else:
        #     for item in steam_api_page['supported_languages']:
        #         if item in lang_list:
        #             d[item] = 1

        if isinstance(spy_api_page['tags'], dict) == True:
            for item in [*spy_api_page['tags'].keys()]:
             if item in tags_list:
              d[item] = 1

        d['id'] = id

        # if spy_api_page['name'] is not None:
        #     d['name'] = spy_api_page['name']
        # else:
        d['name'] = steam_api_page['name']

        d['age'] =  steam_api_page['required_age']

        try:
            if bool(steam_api_page['release_date']['date'] != 'Coming Soon') == True:
                if  len(str(steam_api_page['release_date']['date'])) == 12:
                    d['release_date'] = datetime.strptime(steam_api_page['release_date']['date'], '%b %d, %Y')
                elif len(str(steam_api_page['release_date']['date'])) == 11:
                    d['release_date'] = datetime.strptime(steam_api_page['release_date']['date'], '%b %d, %Y')
                elif len(str(steam_api_page['release_date']['date'])) == 8:
                    d['release_date'] = datetime.strptime(steam_api_page['release_date']['date'], '%b %Y')
                else:
                    d['release_date'] = 0
            else:
                d['release_date'] = 0
        except Exception:
            pass        
        
        # Api Price
        if steam_api_page['is_free'] == False:
            # if spy_api_page['price'] is not None and spy_api_page['price'] != '0' == True:
            #         d['price'] = int(spy_api_page['price']) / 100
            if bool('price_overview' in steam_api_page) == True:
                # if steam_api_page['price_overview']['initial'] is not None == True:
                    d['price'] = steam_api_page['price_overview']['initial'] / 100
            else:
                d['price'] = 0
        else:
            d['price']  = 0


        d['developer'] = spy_api_page['developer']


        try:
            d['num_lang'] = len(spy_api_page['languages'].split(", "))
        except Exception:
            pass

        if isinstance(spy_api_page['tags'], dict) == True:
            d['num_tags'] = len([*spy_api_page['tags'].keys()])

        d['free to play'] = steam_api_page['is_free']

        return d.iloc[0, :].to_dict()  # d.iloc[0, :].T.to_csv('steam_data_id_'+str(id)+'.csv')
     else:

      return pd.DataFrame(0, index=np.arange(len(header_column)), columns=header_column).iloc[0, :].to_dict()

 return pd.DataFrame(0, index=np.arange(len(header_column)), columns=header_column).iloc[0, :].to_dict()

# %%
def pruned_list(original_list):
    return list(filter(lambda x: x != '', map(lambda x: x.strip(), original_list)))
    
def load_list(url):
    response = requests.get(url)
    return pruned_list(response.text.split('\n'))

# %%
tags_ids = ['1084988',
 '1091588',
 '1100686',
 '1100687',
 '1100688',
 '1100689',
 '11014',
 #'1003823',
 '10235',
 '1027',
 '1036',
 '10383',
 '1038',
 '10397',
 '10437',
 '10679',
 '10695',
 '10808',
 '10816',
 '11104',
 '11123',
 '11333',
 '113',
 '11634',
 '117648',
 '12057',
 '12095',
 '12190',
 '12286',
 '122',
 '123332',
 '12472',
 '128',
 '129761',
 '13070',
 '13190',
 '13276',
 '13382',
 '13577',
 '13782',
 '13906',
 '14139',
 '14153',
 '143739',
 '1445',
 '14720',
 '14906',
 '15045',
 '150626',
 '15172',
 '15277',
 '15339',
 '15564',
 '15868',
 '15954',
 '16094',
 '1616',
 '1621',
 '16250',
 '1625',
 '1628',
 '1638',
 '1643',
 '1644',
 '1645',
 '1646',
 '1647',
 '1649',
 '1651',
 '1654',
 '16598',
 '1659',
 '1662',
 '1663',
 '1664',
 '1665',
 '1666',
 '1667',
 '16689',
 '1669',
 '1670',
 '1671',
 '1673',
 '1674',
 '1676',
 '1677',
 '1678',
 '1679',
 '1680',
 '1681',
 '1684',
 '1685',
 '1687',
 '1688',
 '1693',
 '1695',
 '1697',
 '1698',
 '17015',
 '1702']

# %%
tags_dict ={'Name': {492: 'Indie',
  1003823: 'Low Confidence Metric',
  19: 'Action',
  597: 'Casual',
  21: 'Adventure',
  4182: 'Singleplayer',
  599: 'Simulation',
  9: 'Strategy',
  122: 'RPG',
  3871: '2D',
  4166: 'Atmospheric',
  1664: 'Puzzle',
  113: 'Free to Play',
  493: 'Early Access',
  1742: 'Story Rich',
  3859: 'Multiplayer',
  3964: 'Pixel Graphics',
  1684: 'Fantasy',
  4191: '3D',
  4305: 'Colorful',
  4085: 'Anime',
  3839: 'First-Person',
  4667: 'Violent',
  4726: 'Cute',
  3834: 'Exploration',
  1773: 'Arcade',
  6650: 'Nudity',
  4136: 'Funny',
  12095: 'Sexual Content',
  3942: 'Sci-fi',
  1774: 'Shooter',
  21978: 'VR',
  1625: 'Platformer',
  1667: 'Horror',
  1756: 'Great Soundtrack',
  4004: 'Retro',
  4345: 'Gore',
  5350: 'Family Friendly',
  1654: 'Relaxing',
  4026: 'Difficult',
  701: 'Sports',
  1695: 'Open World',
  7208: 'Female Protagonist',
  4106: 'Action-Adventure',
  1662: 'Survival',
  1685: 'Co-op',
  3799: 'Visual Novel',
  1697: 'Third Person',
  699: 'Racing',
  1719: 'Comedy',
  1663: 'FPS',
  128: 'Massively Multiplayer',
  4252: 'Stylized',
  4175: 'Realistic',
  3916: 'Old School',
  4791: 'Top-Down',
  3810: 'Sandbox',
  3968: 'Physics',
  1677: 'Turn-Based',
  3843: 'Online Co-Op',
  1775: 'PvP',
  4255: "Shoot 'Em Up",
  6426: 'Choices Matter',
  5716: 'Mystery',
  1698: 'Point & Click',
  1755: 'Space',
  4094: 'Minimalist',
  4195: 'Cartoony',
  5379: '2D Platformer',
  4342: 'Dark',
  1721: 'Psychological Horror',
  3993: 'Combat',
  12472: 'Management',
  65443: 'Adult Content',
  7481: 'Controller',
  1643: 'Building',
  3798: 'Side Scroller',
  6971: 'Multiple Endings',
  1708: 'Tactical',
  4747: 'Character Customization',
  7368: 'Local Multiplayer',
  5537: 'Puzzle-Platformer',
  4711: 'Replay Value',
  6815: 'Hand-drawn',
  84: 'Design & Illustration',
  4231: 'Action RPG',
  7250: 'Linear',
  7743: '1980s',
  1741: 'Turn-Based Strategy',
  1036: 'Education',
  4057: 'Magic',
  1716: 'Rogue-like',
  5125: 'Procedural Generation',
  4295: 'Futuristic',
  1702: 'Crafting',
  6730: 'PvE',
  3978: 'Survival Horror',
  10695: 'Party-Based RPG',
  3841: 'Local Co-Op',
  3959: 'Rogue-lite',
  5611: 'Mature',
  4325: 'Turn-Based Combat',
  6129: 'Logic',
  8013: 'Software',
  4172: 'Medieval',
  4562: 'Cartoon',
  4434: 'JRPG',
  1659: 'Zombies',
  1738: 'Hidden Object',
  5395: '3D Platformer',
  87: 'Utilities',
  3987: 'Historical',
  1678: 'War',
  4947: 'Romance',
  8945: 'Resource Management',
  1646: 'Hack and Slash',
  14139: 'Turn-Based Tactics',
  1693: 'Classic',
  4486: 'Choose Your Own Adventure',
  4234: 'Short',
  1734: 'Fast-Paced',
  4885: 'Bullet Hell',
  11014: 'Interactive Fiction',
  5984: 'Drama',
  5900: 'Walking Simulator',
  3835: 'Post-apocalyptic',
  4700: 'Movie',
  4604: 'Dark Fantasy',
  1720: 'Dungeon Crawler',
  1038: 'Web Publishing',
  1687: 'Stealth',
  5577: 'RPGMaker',
  1710: 'Surreal',
  1676: 'RTS',
  7332: 'Base Building',
  10397: 'Memes',
  4637: 'Top-Down Shooter',
  9551: 'Dating Sim',
  5851: 'Isometric',
  5154: 'Score Attack',
  13782: 'Experimental',
  4168: 'Military',
  6691: "1990's",
  1621: 'Music',
  1666: 'Card Game',
  5094: 'Narration',
  4115: 'Cyberpunk',
  31275: 'Text-Based',
  3814: 'Third-Person Shooter',
  1743: 'Fighting',
  4400: 'Abstract',
  7948: 'Soundtrack',
  1644: 'Driving',
  9130: 'Hentai',
  4975: '2.5D',
  5608: 'Emotional',
  5752: 'Robots',
  9204: 'Immersive Sim',
  42804: 'Action Roguelike',
  1770: 'Board Game',
  4840: '4 Player Local',
  15045: 'Flight',
  1645: 'Tower Defense',
  30358: 'Nature',
  4695: 'Economy',
  44868: 'LGBTQ+',
  1673: 'Aliens',
  5923: 'Dark Humor',
  3878: 'Competitive',
  5613: 'Detective',
  8369: 'Investigation',
  1759: 'Perma Death',
  17389: 'Tabletop',
  4328: 'City Builder',
  5411: 'Beautiful',
  5711: 'Team-Based',
  379975: 'Clicker',
  5547: 'Arena Shooter',
  4145: 'Cinematic',
  3877: 'Precision Platformer',
  1628: 'Metroidvania',
  16689: 'Time Management',
  3813: 'Real Time Tactics',
  24904: 'NSFW',
  4158: "Beat 'em up",
  17305: 'Strategy RPG',
  10235: 'Life Sim',
  15172: 'Conversation',
  4064: 'Thriller',
  4684: 'Wargame',
  1669: 'Moddable',
  5186: 'Psychological',
  1714: 'Psychedelic',
  21725: 'Tactical RPG',
  12057: 'Tutorial',
  9541: 'Demons',
  872: 'Animation & Modeling',
  8122: 'Level Editor',
  3955: 'Character Action Game',
  1100687: 'Automobile Sim',
  5363: 'Destruction',
  6869: 'Nonlinear',
  4758: 'Twin Stick Shooter',
  5673: 'Modern',
  5030: 'Dystopian',
  8666: 'Runner',
  1751: 'Comic Book',
  4150: 'World War II',
  4598: 'Alternate History',
  3854: 'Lore-Rich',
  6378: 'Crime',
  4736: '2D Fighter',
  1752: 'Rhythm',
  1027: 'Audio Production',
  4236: 'Loot',
  4036: 'Parkour',
  4364: 'Grand Strategy',
  7926: 'Artificial Intelligence',
  13906: 'Game Development',
  10808: 'Supernatural',
  29482: 'Souls-like',
  1665: 'Match 3',
  6276: 'Inventory Management',
  16598: 'Space Sim',
  7569: 'Grid-Based Movement',
  1754: 'MMORPG',
  4474: 'CRPG',
  5794: 'Science',
  19995: 'Dark Comedy',
  16094: 'Mythology',
  15277: 'Philosophical',
  7432: 'Lovecraftian',
  1100689: 'Open World Survival Craft',
  5652: 'Collectathon',
  10816: 'Split Screen',
  784: 'Video Production',
  11123: 'Mouse only',
  17894: 'Cats',
  4190: 'Addictive',
  791774: 'Card Battler',
  32322: 'Deckbuilding',
  6052: 'Noir',
  4242: 'Episodic',
  615955: 'Idler',
  1445: 'Software Training',
  4608: 'Swordplay',
  176981: 'Battle Royale',
  5055: 'eSports',
  1732: 'Voxel',
  4046: 'Dragons',
  4161: 'Real-Time',
  5228: 'Blood',
  4835: '6DOF',
  1777: 'Steampunk',
  4821: 'Mechs',
  220585: 'Colony Sim',
  6506: '3D Fighter',
  11104: 'Vehicular Combat',
  13276: 'Tanks',
  4878: 'Parody',
  4853: 'Political',
  5796: 'Bullet Time',
  4155: 'Class-Based',
  87918: 'Farming Sim',
  6625: 'Time Manipulation',
  29363: '3D Vision',
  1670: '4X',
  1681: 'Pirates',
  24003: 'Word Game',
  7782: 'Cult Classic',
  4508: 'Co-op Campaign',
  198631: 'Mystery Dungeon',
  1717: 'Hex Grid',
  4845: 'Capitalism',
  13070: 'Solitaire',
  5765: 'Gun Customization',
  13190: 'America',
  1688: 'Ninja',
  1651: 'Satire',
  1616: 'Trains',
  3952: 'Gothic',
  4202: 'Trading',
  620519: 'Hero Shooter',
  9564: 'Hunting',
  5502: 'Hacking',
  22602: 'Agriculture',
  18594: 'FMV',
  31579: 'Otome',
  10679: 'Time Travel',
  809: 'Photo Editing',
  7107: 'Real-Time with Pause',
  4102: 'Combat Racing',
  5300: 'God Game',
  5372: 'Conspiracy',
  255534: 'Automation',
  5708: 'Remake',
  6910: 'Naval',
  5981: 'Mining',
  6915: 'Martial Arts',
  1647: 'Western',
  5160: 'Dinosaurs',
  4777: 'Spectacle fighter',
  1730: 'Sokoban',
  9157: 'Underwater',
  1718: 'MOBA',
  21006: 'Underground',
  4754: 'Politics',
  5432: 'Programming',
  1638: 'Dog',
  14153: 'Dungeons & Dragons',
  916648: 'Creature Collector',
  9271: 'Trading Card Game',
  25085: 'Touch-Friendly',
  15564: 'Fishing',
  7478: 'Illuminati',
  1671: 'Superhero',
  1649: 'GameMaker',
  4018: 'Vampire',
  5179: 'Cold War',
  26921: 'Political Sim',
  353880: 'Looter Shooter',
  9592: 'Dynamic Narration',
  5153: 'Kickstarter',
  180368: 'Faith',
  8093: 'Minigames',
  4559: 'Quick-Time Events',
  4376: 'Assassin',
  9994: 'Experience',
  15339: 'Documentary',
  17770: 'Asynchronous Multiplayer',
  4994: 'Naval Combat',
  8253: 'Music-Based Procedural Generation',
  1679: 'Soccer',
  7178: 'Party Game',
  7702: 'Narrative',
  5390: 'Time Attack',
  13382: 'Archery',
  1084988: 'Auto Battler',
  1680: 'Heist',
  1674: 'Typing',
  56690: 'On-Rails Shooter',
  7226: 'Football',
  10383: 'Transportation',
  7108: 'Party',
  6310: 'Diplomacy',
  3934: 'Immersive',
  13577: 'Sailing',
  3920: 'Cooking',
  11333: 'Villain Protagonist',
  5348: 'Mod',
  4184: 'Chess',
  10437: 'Trivia',
  9803: 'Snow',
  7622: 'Offroad',
  3965: 'Epic',
  51306: 'Foreign',
  6702: 'Mars',
  8075: 'TrackIR',
  5230: 'Sequel',
  6041: 'Horses',
  776177: '360 Video',
  7423: 'Sniper',
  5382: 'World War I',
  16250: 'Gambling',
  7113: 'Crowdfunded',
  12190: 'Boxing',
  150626: 'Gaming',
  1736: 'LEGO',
  15954: 'Silent Protagonist',
  454187: 'Traditional Roguelike',
  1091588: 'Roguelike Deckbuilder',
  6621: 'Pinball',
  17015: 'Werewolves',
  3796: 'Based On A Novel',
  1733: 'Unforgiving',
  5310: 'Games Workshop',
  4137: 'Transhumanism',
  6948: 'Rome',
  1723: 'Action RTS',
  12286: 'Warhammer 40K',
  14720: 'Nostalgia',
  7038: 'Golf',
  1100688: 'Medical Sim',
  198913: 'Motorbike',
  61357: 'Electronic Music',
  29855: 'Ambient',
  4520: 'Farming',
  92092: 'Jet',
  1100686: 'Outbreak Sim',
  71389: 'Spelling',
  123332: 'Bikes',
  19780: 'Submarine',
  1746: 'Basketball',
  856791: 'Asymmetric VR',
  745697: 'Social Deduction',
  922563: 'Roguevania',
  22955: 'Mini Golf',
  4291: 'Spaceships',
  769306: 'Escape Room',
  14906: 'Intentionally Awkward Controls',
  47827: 'Wrestling',
  17337: 'Lemmings',
  189941: 'Instrumental Music',
  17927: 'Pool',
  5727: 'Baseball',
  5914: 'Tennis',
  324176: 'Hockey',
  1753: 'Skateboarding',
  11634: 'Vikings',
  15868: 'Motocross',
  233824: 'Feature Film',
  96359: 'Skating',
  143739: 'Electronic',
  19568: 'Cycling',
  7328: 'Bowling',
  337964: 'Rock Music',
  27758: 'Voice Control',
  5407: 'Benchmark',
  129761: 'ATV',
  7309: 'Skiing',
  28444: 'Snowboarding',
  8461: 'Well-Written',
  603297: 'Hardware',
  117648: '8-bit Music',
  252854: 'BMX',
  348922: 'Steam Machine',
  5941: 'Reboot'}}

# %%
# Checks for already made DataFrames
id_check_list = []
for filename in os.listdir(path1):
    if filename.endswith('.xlsx'):
        # csvtable_list.append(pd.read_csv(filename, sep=","))
        id_check_list.append(filename[:-4].split("_")[2])

header_column = ['name', 'age', 'release_date', 'developer', 'price'] + lang_list + ['num_lang'] + tags_list + [
    'num_tags']

for item in tqdm(tags_ids):
    if str(item)+'.' not in id_check_list:
        os.chdir(path3)

        input_df = pd.read_csv('dataframe_id_'+str(item)+'_'+str(tags_dict['Name'][int(item)])+'.csv', sep=",")

        rows_list = []
        for row in tqdm(input_df.iloc[:, -1]):

                sleep(3) # poor mans rate limit
                rows_list.append(steam_info(row))

        df = pd.DataFrame(rows_list)
        #save dataframes
        os.chdir(path1)

        df.to_excel('dataframe_id_' + item + '.xlsx', index=False)

        print(f'dataframe id:  {str(item)} - Done')
# Out:
# ...
#  60%|█████▉    | 52/87 [03:40<02:27,  4.20s/it]
# ...
# ...
#  25%|██▌       | 23/91 [01:40<05:10,  4.57s/it]
# dataframe id:  1027 - Done
# dataframe id:  1036 - Done
# dataframe id:  10383 - Done
# dataframe id:  1038 - Done
# dataframe id:  10397 - Done
# dataframe id:  10437 - Done
# dataframe id:  10679 - Done
# dataframe id:  10695 - Done
# dataframe id:  10808 - Done
# dataframe id:  10816 - Done
# dataframe id:  11104 - Done
# dataframe id:  11123 - Done
# dataframe id:  11333 - Done
# dataframe id:  113 - Done
# dataframe id:  11634 - Done
# dataframe id:  117648 - Done
# dataframe id:  12057 - Done
# dataframe id:  12095 - Done
# dataframe id:  12190 - Done
# dataframe id:  12286 - Done
# dataframe id:  122 - Done
# dataframe id:  123332 - Done
# dataframe id:  12472 - Done
# dataframe id:  128 - Done
# dataframe id:  129761 - Done
# dataframe id:  13070 - Done
# dataframe id:  13190 - Done
